# %% [markdown]
# Model integration using LLM's

# %%
import os
from dotenv import load_dotenv

load_dotenv()

os.environ["GEMINI_API_KEY"] = os.getenv("GEMINI_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model=init_chat_model("gpt-4o")
model
# Out:
# ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.4.7', 'langchain': '1.3.9', 'langchain-openai': '1.3.2'}}, output_version=None, profile={'name': 'GPT-4o', 'release_date': '2024-05-13', 'last_updated': '2024-08-06', 'open_weights': False, 'max_input_tokens': 128000, 'max_output_tokens': 16384, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x000002B50DA282F0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000002B50DA28EC0>, root_client=<openai.OpenAI object at 0x000002B50CD09BE0>, root_async_client=<openai.AsyncOpenAI object at 0x000002B50DA28C20>, model_name='gpt-4o', model_kwargs={}, openai_api_key=SecretStr('**********'), openai_proxy=None, stream_usage=True, stream_chunk_timeout=120.0)

# %% [markdown]
# HOW TO CALL A GOOGLE GEMINI MODEL

# %%
import os
from langchain.chat_models import init_chat_model
os.environ["GEMINI_API_KEY"] = os.getenv("GEMINI_API_KEY")

model=init_chat_model("google_genai:gemini-2.5-flash-lite")
response=model.invoke("Why do parrot talk?")
response
# Out:
# AIMessage(content='Parrots talk for a variety of fascinating reasons, and it\'s not just about mimicking human sounds. It\'s a complex behavior rooted in their natural instincts and social needs. Here\'s a breakdown of why parrots talk:\n\n**1. Social Bonding and Communication:**\n\n* **Flocking Behavior:** Parrots are highly social animals that live in large flocks in the wild. Communication is crucial for maintaining group cohesion, alerting others to danger, finding food, and coordinating movements. Talking, or vocalizing in general, is their primary way of doing this.\n* **Mimicry as a Form of Social Acceptance:** In the wild, parrots learn the calls and songs of their flock members. By mimicking sounds, they can blend in, show they belong, and establish social bonds. When a parrot mimics human sounds, it\'s essentially trying to integrate these new sounds into its social environment.\n\n**2. Intelligence and Cognitive Abilities:**\n\n* **Problem Solvers and Learners:** Parrots are incredibly intelligent birds. They possess advanced cognitive abilities, including problem-solving skills and the capacity to learn. Learning to mimic sounds is a demonstration of this learning ability.\n* **Understanding Context (to some extent):** While often perceived as simply repeating, some parrots can learn to associate words or phrases with specific objects, actions, or people. They might say "hello" when someone enters a room or "goodbye" when they leave. This suggests a rudimentary understanding of the context in which sounds are used.\n\n**3. Attention Seeking and Interaction:**\n\n* **Desire for Interaction:** Parrots are curious and often crave interaction with their flock (which, in captivity, is you!). Talking is a way for them to get your attention, solicit interaction, and engage with their environment.\n* **Reinforcement:** When a parrot talks and receives a positive response (like praise, treats, or continued interaction), they learn that this behavior is rewarding. This positive reinforcement encourages them to vocalize more.\n\n**4. Playfulness and Entertainment:**\n\n* **Vocal Exploration:** Parrots are naturally vocal and enjoy experimenting with sounds. Talking can be a form of play for them, a way to explore the acoustic possibilities of their environment.\n* **Expressing Emotion (indirectly):** While they don\'t "talk" in the human sense of conveying complex thoughts and emotions, their vocalizations can reflect their mood. Excited chirps and whistles might accompany happy moments, while certain squawks might indicate frustration or alarm.\n\n**5. Survival Instincts (in the wild):**\n\n* **Alarm Calls:** In their natural habitat, parrots use a variety of calls to warn their flock of predators or other dangers.\n* **Mate Attraction:** Vocalizations play a role in courtship and attracting mates.\n\n**Types of Parrot Vocalizations:**\n\nIt\'s important to distinguish between general vocalizations and "talking" (mimicry). Parrots naturally:\n\n* **Chirp and Squawk:** These are their innate vocalizations used for general communication.\n* **Sing:** Many parrot species have complex songs.\n* **Mimic:** This is the ability to reproduce sounds they hear, including human speech, other animal sounds, and environmental noises.\n\n**In summary, parrots talk because:**\n\n* **They are social creatures programmed for communication.**\n* **They are intelligent and capable of learning.**\n* **They seek interaction and attention.**\n* **It\'s a form of play and exploration.**\n* **It can be reinforced by their environment.**\n\nWhile they may not understand the semantic meaning of every word they say, their ability to mimic and sometimes associate sounds with context is truly remarkable and a testament to their intelligence and complex social lives.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019eda14-6f78- ...
