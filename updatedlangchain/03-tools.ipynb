# %% [markdown]
# Tools making and calling

# %%
import os
from langchain.chat_models import init_chat_model
os.environ["GEMINI_API_KEY"] = os.getenv("GEMINI_API_KEY")

model=init_chat_model("google_genai:gemini-2.5-flash-lite")
response=model.invoke("Why do parrot talk?")
response
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File d:\Projects\langchainnew\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3234, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3233 try:
# -> 3234     response: GenerateContentResponse = self.client.models.generate_content(
#    3235         **request,
#    3236     )
#    3237 except ClientError as e:
#
# File d:\Projects\langchainnew\.venv\Lib\site-packages\google\genai\models.py:6480, in Models.generate_content(self, model, contents, config)
#    6479 i += 1
# -> 6480 response = self._generate_content(
#    6481     model=model, contents=contents, config=parsed_config
#    6482 )
#    6484 function_map = _extra_utils.get_function_map(parsed_config)
#
# File d:\Projects\langchainnew\.venv\Lib\site-packages\google\genai\models.py:4916, in Models._generate_content(self, model, contents, config)
#    4914 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4916 response = self._api_client.request(
#    4917     'post', path, request_dict, http_options
#    4918 )
#    4920 if config is not None and getattr(
#    4921     config, 'should_return_http_response', None
#    4922 ):
#
# File d:\Projects\langchainnew\.venv\Lib\site-packages\google\genai\_api_client.py:1611, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1608 http_request = self._build_request(
#    1609     http_method, path, request_dict, http_options
#    1610 )
# -> 1611 response = self._request(http_request, http_options, stream=False)
#    1612 response_body = (
#    1613     response.response_stream[0] if response.response_stream else ''
#    1614 )
#
# File d:\Projects\langchainnew\.venv\Lib\site-packages\google\genai\_api_client.py:1402, in BaseApiClient._request(self, http_request, http_options, stream)
#    1401     retry = tenacity.Retrying(**retry_kwargs)
# -> 1402     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1404 return self._retry(self._request_once, http_request, stream)
#
# File d:\Projects\langchainnew\.venv\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File d:\Projects\langchainnew\.venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File d:\Projects\langchainnew\.venv\Lib\site-packages\tenacity\__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     392 if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393     self._add_action_func(lambda rs: rs.outcome.result())
#     394     return
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\concurrent\futures\_base.py:443, in Future.result(self, timeout)
#     442 elif self._state == FINISHED:
# --> 443     return self.__get_result()
#     445 self._condition.wait(timeout)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\concurrent\futures\_base.py:395, in Future.__get_result(self)
#     394 try:
# --> 395     raise self._exception
#     396 finally:
#     397     # Break a reference cycle with the exception in self._exception
#
# File d:\Projects\langchainnew\.venv\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File d:\Projects\langchainnew\.venv\Lib\site-packages\google\genai\_api_client.py:1381, in BaseApiClient._request_once(self, http_request, stream)
#    1380   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1381 errors.APIError.raise_for_response(response)
#    1382 return HttpResponse(
#    1383     response.headers, response if stream else [response.text]
#    1384 )
#
# File d:\Projects\langchainnew\.venv\Lib\site-packages\google\genai\errors.py:155, in APIError.raise_for_response(cls, response)
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File d:\Projects\langchainnew\.venv\Lib\site-packages\google\genai\errors.py:184, in APIError.raise_error(cls, status_code, response_json, response)
#     183 if 400 <= status_code < 500:
# --> 184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
#
# ClientError: 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/gemini-1.5-flash is not found for API version v1beta, or is not supported for generateContent. Call ModelService.ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[3], line 6
#       2 from langchain.chat_models import init_chat_model
#       3 os.environ["GEMINI_API_KEY"] = os.getenv("GEMINI_API_KEY")
#       4
#       5 model=init_chat_model("google_genai:gemini-1.5-flash")
# ----> 6 response=model.invoke("Why do parrot talk?")
#       7 response
#
# File d:\Projects\langchainnew\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:2701, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2698         msg = "Tools are already defined.code_execution tool can't be defined"
#    2699         raise ValueError(msg)
# -> 2701 return super().invoke(input, config, stop=stop, **kwargs)
#
# File d:\Projects\langchainnew\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File d:\Projects\langchainnew\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\Projects\langchainnew\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File d:\Projects\langchainnew\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File d:\Projects\langchainnew\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3238, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3234     response: GenerateContentResponse = self.client.models.generate_content(
#    3235         **request,
#    3236     )
#    3237 except ClientError as e:
# -> 3238     _handle_client_error(e, request)
#    3240 return _response_to_result(response)
#
# File d:\Projects\langchainnew\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:169, in _handle_client_error(e, request)
#     167 model_name = request.get("model", "unknown")
#     168 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 169 raise ChatGoogleGenerativeAIError(msg) from e
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-1.5-flash' (NOT_FOUND): 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/gemini-1.5-flash is not found for API version v1beta, or is not supported for generateContent. Call ModelService.ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}
